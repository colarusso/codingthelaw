# %%
import csv
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope = ['https://spreadsheets.google.com/feeds']
document_key = "13bsf7rP9ubfBSX7-hK3QayZIaUkTxrXaOZqGsfLjWX4"
credentials = ServiceAccountCredentials.from_json_keyfile_name('../../../../../SheetsBot-32718db5596a.json', scope)
csvfile = "output.csv"
gc = gspread.authorize(credentials)
wks = gc.open_by_key(document_key)
worksheet = wks.worksheet("Form Responses 1")
list_of_lists = worksheet.get_all_values()
with open(csvfile, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    writer.writerows(list_of_lists)

import pandas as pd
output = pd.read_csv(csvfile)
output[:20]
# Out:
#              Timestamp           Project Name            Your Name  \
# 0     9/1/2016 1:02:56          Penny Pincher        Peter Gibbons
# 1   8/31/2016 21:27:04          Penny Pincher       Michael Bolton
# 2   8/31/2016 21:27:24          Penny Pincher  Samir Nagheenanajar
# 3    9/13/2016 0:26:03    Testing Your Python             Some Guy
# 4    9/13/2016 0:52:19                Another                 Test
# 5    9/13/2016 1:49:45                    And                 The
# 6   9/15/2016 14:53:04           Cool Project       Harrison Lebov
# 7   9/15/2016 15:40:41        Argos Remembers        Anthony Davis
# 8   1/19/2017 23:56:43  Lawyerist TPS reports        Greg Claesses
# 9    2/7/2017 11:11:00       Cool Project 2.0                  Sol
# 10    2/9/2017 2:12:29                 Coding                 Tony
# 11    2/9/2017 2:13:18                     dd                   dd
# 12    2/9/2017 2:13:24                     bb                   ed
# 13  4/11/2017 17:38:06                    Wow                Thank
# 14   7/10/2017 8:36:59        Test Automation                Namer
#
#           Your Supervisor
# 0           Bill Lumbergh
# 1           Bill Lumbergh
# 2           Bill Lumbergh
# 3            Another Dude
# 4         Will this work?
# 5                    Last
# 6        David Colarusso
# 7   Anthony Michael Davis
# 8                    Odin
# 9                     Sam
# 10                  Jesse
# 11                     22
# 12                     ee
# 13                   You!
# 14                    Sup
